# %%
# inspiration: https://docs.google.com/spreadsheets/d/1wZhPLMCHKJvwOkP4juclhjFgqIY8fQFMemwKL2c64vk/htmlview row 1252
# senate data: https://senatestockwatcher.com/api
# house data: https://housestockwatcher.com/api
# historical legiislator data: https://github.com/unitedstates/congress-legislators

# %%
import pandas as pd

# %% [markdown]
# ## Process legislator file

# %%
congress_historical = pd.read_csv("https://theunitedstates.io/congress-legislators/legislators-historical.csv",
                                  usecols=["first_name","middle_name", "last_name", "full_name", "type", "party"])

congress_historical = congress_historical[(congress_historical.type == "sen") & (congress_historical.full_name.notna())]

congress_current = pd.read_csv("https://theunitedstates.io/congress-legislators/legislators-current.csv",
                               usecols=["first_name","middle_name", "last_name", "full_name", "type", "party"])

congress_current = congress_current[(congress_current.type == "sen") & (congress_current.full_name.notna())]

congress = pd.concat([congress_historical, congress_current])

congress.head()
# Out:
#        last_name first_name middle_name             full_name type       party
# 11634     Inouye     Daniel          K.      Daniel K. Inouye  sen    Democrat
# 11635      Akaka     Daniel    Kahikina       Daniel K. Akaka  sen    Democrat
# 11636   Bingaman       Jeff         NaN         Jeff Bingaman  sen    Democrat
# 11637     Conrad       Kent        Kent           Kent Conrad  sen    Democrat
# 11638  Hutchison        Kay      Bailey  Kay Bailey Hutchison  sen  Republican

# %%
congress["name_cleaned"] = congress["full_name"].replace({", IV": "", "III": ""}, regex=True)

congress.name_cleaned.unique()
# Out:
# array(['Daniel K. Inouye', 'Daniel K. Akaka', 'Jeff Bingaman',
#        'Kent Conrad', 'Kay Bailey Hutchison', 'Herb Kohl',
#        'Joseph I. Lieberman', 'Richard G. Lugar', 'Ben Nelson',
#        'Olympia J. Snowe', 'Jim Webb', 'Scott P. Brown', 'Jim DeMint',
#        'John F. Kerry', 'Frank R. Lautenberg', 'William M. Cowan',
#        'Jeff Chiesa', 'Max Baucus', 'Mark Begich', 'Saxby Chambliss',
#        'Kay R. Hagan', 'Tom Harkin', 'Tim Johnson', 'Mary L. Landrieu',
#        'Carl Levin', 'Mark L. Pryor', 'John D. Rockefeller', 'Mark Udall',
#        'Tom Coburn', 'John E. Walsh', 'Mike Johanns', 'Kelly Ayotte',
#        'Barbara Boxer', 'Daniel Coats', 'Mark Kirk',
#        'Barbara A. Mikulski', 'Harry Reid', 'David Vitter',
#        'Jeff Sessions', 'Al Franken', 'Luther Strange', 'Thad Cochran',
#        'John McCain', 'Jon Kyl', 'Bob Corker', 'Orrin G. Hatch',
#        'Claire McCaskill', 'Bill Nelson', 'Joe Donnelly', 'Jeff Flake',
#        'Dean Heller', 'Heidi Heitkamp', 'Johnny Isakson',
#        'Martha McSally', 'Lamar Alexander', 'Michael B. Enzi',
#        'Pat Roberts', 'Tom Udall', 'Cory Gardner', 'David Perdue',
#        'Doug Jones', 'Kamala D. Harris', 'Kelly Loeffler',
#        'Sherrod Brown', 'Maria Cantwell', 'Benjamin L. Cardin',
#        'Thomas R. Carper', 'Robert P. Casey, Jr.', 'Dianne Feinstein',
#        'Amy Klobuchar', 'Robert Menendez', 'Bernard Sanders',
#        'Debbie Stabenow', 'Jon Tester', 'Sheldon Whitehouse',
#        'John Barrasso', 'Roger F. Wicker', 'Susan M. Collins',
#        'John Cornyn', 'Richard J. Durbin', 'Lindsey Graham',
#        'James M. Inhofe', 'Mitch McConnell', 'Jeff Merkley', 'Jack Reed',
#        'James E. Risch', 'Jeanne Shaheen', 'Mark R. Warner',
#        'Kirsten E. Gillibrand', 'Christopher A. Coons', 'Joe Manchin, ',
#        'Tammy Baldwin', 'Michael F. Bennet', 'Marsha Blackburn',
#        'Richard Blumenthal', 'Roy Blunt', 'John Boozman', 'Richard Burr',
#        'Shelley Moore Capito', 'Bill Cassidy', 'Mike Crapo',
#        'Chuck Grassley', 'Martin Heinrich', 'Mazie K. Hirono',
#        'John Hoeven', 'Ron Johnson', 'James Lankford', 'Patrick J. Leahy',
#        'Mike Lee', 'Ben Ray Luján', 'Edward J. Markey', 'Jerry Moran',
#        'Lisa Murkowski', 'Christopher Murphy', 'Patty Murray',
#        'Rand Paul', 'Gary C. Peters', 'Rob Portman', 'Marco Rubio',
#        'Charles E. Schumer', 'Tim Scott', 'Richard C. Shelby',
#        'John Thune', 'Patrick J. Toomey', 'Chris Van Hollen', 'Ron Wyden',
#        'Todd Young', 'Brian Schatz', 'Tom Cotton', 'Kyrsten Sinema',
#        'Tammy Duckworth', 'Elizabeth Warren', 'Angus S. King, Jr.',
#        'Steve Daines', 'Kevin Cramer', 'Deb Fischer', 'Ted Cruz',
#        'Tim Kaine', 'Cory A. Booker', 'Dan Sullivan', 'Joni Ernst',
#        'Thom Tillis', 'Mike Rounds', 'Ben Sasse', 'John Kennedy',
#        'Margaret Wood Hassan', 'Catherine Cortez Masto', 'Roger Marshall',
#        'Jacky Rosen', 'Tina Smith', 'Cindy Hyde-Smith', 'Rick Scott',
#        'Mike Braun', 'Josh Hawley', 'Mitt Romney', 'Mark Kelly',
#        'Cynthia M. Lummis', 'Tommy Tuberville', 'John W. Hickenlooper',
#        'Bill Hagerty', 'Alex Padilla', 'Jon Ossoff', 'Raphael G. Warnock'],
#       dtype=object)

# %%
def clean_congress_name(fullname):
    names = fullname.split(" ")
    fullname = names[0] + " " + names[-1]
    return fullname

congress["fullname_cleaned"] = congress["name_cleaned"].apply(clean_congress_name)
congress.head()
# Out:
#        last_name first_name middle_name             full_name type  \
# 11634     Inouye     Daniel          K.      Daniel K. Inouye  sen
# 11635      Akaka     Daniel    Kahikina       Daniel K. Akaka  sen
# 11636   Bingaman       Jeff         NaN         Jeff Bingaman  sen
# 11637     Conrad       Kent        Kent           Kent Conrad  sen
# 11638  Hutchison        Kay      Bailey  Kay Bailey Hutchison  sen
#
#             party          name_cleaned fullname_cleaned
# 11634    Democrat      Daniel K. Inouye    Daniel Inouye
# 11635    Democrat       Daniel K. Akaka     Daniel Akaka
# 11636    Democrat         Jeff Bingaman    Jeff Bingaman
# 11637    Democrat           Kent Conrad      Kent Conrad
# 11638  Republican  Kay Bailey Hutchison    Kay Hutchison

# %%
congress.to_csv("data/senators.csv", index=False)

# %% [markdown]
# ## Get daily senate trade summary file

# %%
# url = "https://senate-stock-watcher-data.s3-us-west-2.amazonaws.com/aggregate/all_daily_summaries.json"
txns = pd.read_json("https://senate-stock-watcher-data.s3-us-west-2.amazonaws.com/aggregate/all_transactions.json")

print(txns.shape)
txns.head(1)
# Out:
# (8831, 11)
#   transaction_date   owner ticker  \
# 0       08/30/2021  Spouse   BABA
#
#                                    asset_description asset_type         type  \
# 0  Alibaba Group Holding Limited American Depositary      Stock  Sale (Full)
#
#              amount                                            comment  \
# 0  $1,001 - $15,000  Due to standing separation agreement with fina...
#
#               senator                                           ptr_link  \
# 0  Sheldon Whitehouse  https://efdsearch.senate.gov/search/view/ptr/2...
#
#   disclosure_date
# 0      09/13/2021

# %%
txns = txns[["senator", "transaction_date", "disclosure_date", "ticker", "asset_description", "asset_type", "amount"]]
txns.head()
# Out:
#               senator transaction_date disclosure_date ticker  \
# 0  Sheldon Whitehouse       08/30/2021      09/13/2021   BABA
# 1  Sheldon Whitehouse       08/27/2021      09/13/2021     --
# 2  Sheldon Whitehouse       08/30/2021      09/13/2021   MCHP
# 3  Sheldon Whitehouse       08/30/2021      09/13/2021      T
# 4    Patrick J Toomey       01/16/2021      09/09/2021     --
#
#                                    asset_description        asset_type  \
# 0  Alibaba Group Holding Limited American Depositary             Stock
# 1  MACYS RETAIL HLDGS INC <div class="text-muted"...    Corporate Bond
# 2   Microchip Technology Incorporated - Common Stock             Stock
# 3                                      AT&amp;T Inc.             Stock
# 4  Fitso (Exchanged) <br> Zomato (Received) <div ...  Non-Public Stock
#
#               amount
# 0   $1,001 - $15,000
# 1  $15,001 - $50,000
# 2  $15,001 - $50,000
# 3  $15,001 - $50,000
# 4   $1,001 - $15,000

# %%
txns["name_cleaned"] = txns["senator"].replace({", Jr.": "", ", Iv" : "", "Ladda ": "", "Rafael": "Ted", ", Iii": ""}, regex=True)
txns.name_cleaned.unique()
# Out:
# array(['Sheldon Whitehouse', 'Patrick J Toomey', 'Thomas H Tuberville',
#        'Mark R Warner', 'Thomas R Carper', 'Christopher A Coons',
#        'Roger W Marshall', 'Shelley M Capito', 'John Hoeven', 'Rand Paul',
#        'John W Hickenlooper', 'Gary C Peters', 'Angus S King',
#        'Susan M Collins', 'Michael F Bennet', 'Ron L Wyden',
#        'William F Hagerty', 'Rick Scott', 'John Boozman',
#        'A. Mitchell Mcconnell', 'Mike Rounds', 'Jerry Moran,',
#        'Richard M Burr', 'Tina Smith', 'Tammy Duckworth',
#        'Daniel S Sullivan', 'James M Inhofe', 'Pat Roberts',
#        'Jacklyn S Rosen', 'William Cassidy', 'Richard Blumenthal',
#        'David A Perdue , Jr', 'Kelly Loeffler', 'Timothy M Kaine',
#        'Jeanne Shaheen', 'Ron Johnson', 'Roger F Wicker',
#        'Dianne Feinstein', 'Lamar Alexander', 'Roy Blunt',
#        'John N Kennedy', 'Ted E Cruz', 'Thomas Udall', 'John F Reed',
#        'Thomas R Tillis', 'John A Barrasso', 'Robert P Casey',
#        'Robert J Portman', 'Benjamin L Cardin', 'Joseph Manchin',
#        'Michael D Crapo', 'Patty Murray', 'Steve Daines',
#        'Chris Van Hollen', 'John Cornyn', 'Maria Cantwell',
#        'Michael  B Enzi', 'Cory A Booker', 'Ron Wyden', 'Jack Reed',
#        'Thad Cochran', 'Roy D Blunt', 'Maria E Cantwell',
#        'Ronald L Wyden', 'Michael B Enzi', 'Ted Edward (Ted) Cruz',
#        'Elizabeth Warren', 'Richard C Shelby', 'Tom S Udall'],
#       dtype=object)

# %%
def get_first_last_name(row):
    fullname = row["name_cleaned"]
    names = fullname.split(" ")
    first_name = names[0]
    last_name = names[-1]
    full_name = f"{first_name} {last_name}"
    return full_name, first_name, last_name

# %%
txns[["full_name", "first_name", "last_name"]] = txns.apply(get_first_last_name, axis=1, result_type="expand")
txns.head()
# Out:
#               senator transaction_date disclosure_date ticker  \
# 0  Sheldon Whitehouse       08/30/2021      09/13/2021   BABA
# 1  Sheldon Whitehouse       08/27/2021      09/13/2021     --
# 2  Sheldon Whitehouse       08/30/2021      09/13/2021   MCHP
# 3  Sheldon Whitehouse       08/30/2021      09/13/2021      T
# 4    Patrick J Toomey       01/16/2021      09/09/2021     --
#
#                                    asset_description        asset_type  \
# 0  Alibaba Group Holding Limited American Depositary             Stock
# 1  MACYS RETAIL HLDGS INC <div class="text-muted"...    Corporate Bond
# 2   Microchip Technology Incorporated - Common Stock             Stock
# 3                                      AT&amp;T Inc.             Stock
# 4  Fitso (Exchanged) <br> Zomato (Received) <div ...  Non-Public Stock
#
#               amount        name_cleaned first_name   last_name  \
# 0   $1,001 - $15,000  Sheldon Whitehouse    Sheldon  Whitehouse
# 1  $15,001 - $50,000  Sheldon Whitehouse    Sheldon  Whitehouse
# 2  $15,001 - $50,000  Sheldon Whitehouse    Sheldon  Whitehouse
# 3  $15,001 - $50,000  Sheldon Whitehouse    Sheldon  Whitehouse
# 4   $1,001 - $15,000    Patrick J Toomey    Patrick      Toomey
#
#             full_name
# 0  Sheldon Whitehouse
# 1  Sheldon Whitehouse
# 2  Sheldon Whitehouse
# 3  Sheldon Whitehouse
# 4      Patrick Toomey

# %%
txns.to_csv("data/txns_09132021.csv", index=False)

# %% [markdown]
# ## Join congress to txns

# %%
merged = txns.merge(congress,
                    left_on="full_name",
                    right_on="fullname_cleaned",
                    how="left")
merged.head()
# Out:
#               senator transaction_date disclosure_date ticker  \
# 0  Sheldon Whitehouse       08/30/2021      09/13/2021   BABA
# 1  Sheldon Whitehouse       08/27/2021      09/13/2021     --
# 2  Sheldon Whitehouse       08/30/2021      09/13/2021   MCHP
# 3  Sheldon Whitehouse       08/30/2021      09/13/2021      T
# 4    Patrick J Toomey       01/16/2021      09/09/2021     --
#
#                                    asset_description        asset_type  \
# 0  Alibaba Group Holding Limited American Depositary             Stock
# 1  MACYS RETAIL HLDGS INC <div class="text-muted"...    Corporate Bond
# 2   Microchip Technology Incorporated - Common Stock             Stock
# 3                                      AT&amp;T Inc.             Stock
# 4  Fitso (Exchanged) <br> Zomato (Received) <div ...  Non-Public Stock
#
#               amount      name_cleaned_x first_name_x last_name_x  \
# 0   $1,001 - $15,000  Sheldon Whitehouse      Sheldon  Whitehouse
# 1  $15,001 - $50,000  Sheldon Whitehouse      Sheldon  Whitehouse
# 2  $15,001 - $50,000  Sheldon Whitehouse      Sheldon  Whitehouse
# 3  $15,001 - $50,000  Sheldon Whitehouse      Sheldon  Whitehouse
# 4   $1,001 - $15,000    Patrick J Toomey      Patrick      Toomey
#
#           full_name_x last_name_y first_name_y middle_name  \
# 0  Sheldon Whitehouse  Whitehouse      Sheldon         NaN
# 1  Sheldon Whitehouse  Whitehouse      Sheldon         NaN
# 2  Sheldon Whitehouse  Whitehouse      Sheldon         NaN
# 3  Sheldon Whitehouse  Whitehouse      Sheldon         NaN
# 4      Patrick Toomey      Toomey      Patrick          J.
#
#           full_name_y type       party      name_cleaned_y    fullname_cleaned
# 0  Sheldon Whitehouse  sen    Democrat  Sheldon Whitehouse  Sheldon Whitehouse
# 1  Sheldon Whitehouse  sen    Democrat  Sheldon Whitehouse  Sheldon Whitehouse
# 2  Sheldon Whitehouse  sen    Democrat  Sheldon Whitehouse  Sheldon Whitehouse
# 3  Sheldon Whitehouse  sen    Democrat  Sheldon Whitehouse  Sheldon Whitehouse
# 4   Patrick J. Toomey  sen  Republican   Patrick J. Toomey      Patrick Toomey

# %%
merged[merged.fullname_cleaned.isna()].full_name_x.unique()
# Out:
# array(['Thomas Tuberville', 'Angus King', 'William Hagerty',
#        'A. Mcconnell', 'Jerry Moran,', 'Daniel Sullivan', 'Jacklyn Rosen',
#        'William Cassidy', 'David Jr', 'Timothy Kaine', 'Thomas Udall',
#        'John Reed', 'Thomas Tillis', 'Robert Casey', 'Robert Portman',
#        'Joseph Manchin', 'Michael Crapo', 'Ronald Wyden'], dtype=object)
